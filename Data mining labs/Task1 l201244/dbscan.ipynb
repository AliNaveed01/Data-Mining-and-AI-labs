# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from collections import Counter

# %%
# Perform K-medoids clustering on basic2.csv
file1 = pd.read_csv('basic2.csv')
file2 = pd.read_csv('blob.csv')
file3 = pd.read_csv('boxes3.csv')
file4 = pd.read_csv('dart.csv')
file5 = pd.read_csv('outliers.csv')
file6 = pd.read_csv('spiral2.csv')

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
# Initialize the DBSCAN clustering algorithm
dbscan = DBSCAN(eps=0.1, min_samples=5)

# Fit the algorithm to the data
dbscan.fit(file1)

# Get the cluster labels for each data point
labels = dbscan.labels_

# Plot the data colored by cluster label
plt.scatter(file1.iloc[:, 0], file1.iloc[:, 1], c=labels)
plt.show()

# %%
# for dataset 1

#scale the data 
scaled_data = StandardScaler().fit_transform(file2)

db = DBSCAN(eps=0.3, min_samples=10).fit(file2)
labels = db.labels_

#visualize the results

plt.scatter(file2['x'], file2['y'], c=labels, cmap = "jet")
plt.title('DBSCAN Clustering for Dataset 1')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# for dataset 1

#scale the data 
scaled_data = StandardScaler().fit_transform(file3)

db = DBSCAN(eps=0.3, min_samples=10).fit(file3)
labels = db.labels_

#visualize the results

plt.scatter(file3['x'], file3['y'], c=labels, cmap = "jet")
plt.title('DBSCAN Clustering for Dataset 1')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# for dataset 1

#scale the data 
scaled_data = StandardScaler().fit_transform(file4)

db = DBSCAN(eps=0.3, min_samples=10).fit(file4)
labels = db.labels_

#visualize the results

plt.scatter(file4['x'], file4['y'], c=labels, cmap = "jet")
plt.title('DBSCAN Clustering for Dataset 1')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# for dataset 1

#scale the data 
scaled_data = StandardScaler().fit_transform(file6)

db = DBSCAN(eps=0.3, min_samples=10).fit(file6)
labels = db.labels_

#visualize the results

plt.scatter(file6['x'], file6['y'], c=labels, cmap = "jet")
plt.title('DBSCAN Clustering for Dataset 1')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
